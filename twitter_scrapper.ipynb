# %%
# !twscrape add_accounts worker.txt username:password:email:email_password
# Out:
# 2023-11-15 00:37:57.311 | WARNING  | twscrape.accounts_pool:add_account:76 - Account csce60637593 already exists

# %%
# !twscrape login_accounts
# Out:
# {'total': 0, 'success': 0, 'failed': 0}

# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level

async def main():
    api = API()  # or API("path-to.db") - default is `accounts.db`
    # ADD ACCOUNTS (for CLI usage see BELOW)
    # csce60637593:20010305:csce606worker1@gmail.com:P@ssw0rd!2001
    # await api.pool.add_account("csce60637593", "20010305", "csce606worker1@gmail.com", "P@ssw0rd!2001")
    # await api.pool.add_account("user2", "pass2", "u2@example.com", "mail_pass2")
    # await api.pool.login_all()

    # or add account with COOKIES (with cookies login not required)
    # cookies = "abc=12; ct0=xyz"  # or '{"abc": "12", "ct0": "xyz"}'
    cookies = "mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\""
    await api.pool.add_account("csce60637593", "20010305", "csce606worker1@gmail.com", "P@ssw0rd!2001", cookies= cookies)
    # await api.pool.add_account("user3", "pass3", "u3@mail.com", "mail_pass3", cookies=cookies)
    await api.pool.login_all()

    # add account with PROXY
    # proxy = "http://login:pass@example.com:8080"
    # await api.pool.add_account("user4", "pass4", "u4@mail.com", "mail_pass4", proxy=proxy)

    # API USAGE

    # search (latest tab)
    await gather(api.search("elon musk", limit=20))  # list[Tweet]
    # change search tab (product), can be: Top, Latest (default), Media
    await gather(api.search("elon musk", limit=20, kv={"product": "Top"}))

    # tweet info
    tweet_id = 20
    await api.tweet_details(tweet_id)  # Tweet
    await gather(api.retweeters(tweet_id, limit=20))  # list[User]
    await gather(api.favoriters(tweet_id, limit=20))  # list[User]

    # get user by login
    user_login = "xdevelopers"
    await api.user_by_login(user_login)  # User

    # user info
    user_id = 2244994945
    await api.user_by_id(user_id)  # User
    await gather(api.followers(user_id, limit=20))  # list[User]
    await gather(api.following(user_id, limit=20))  # list[User]
    await gather(api.user_tweets(user_id, limit=20))  # list[Tweet]
    await gather(api.user_tweets_and_replies(user_id, limit=20))  # list[Tweet]

    # list info
    list_id = 123456789
    await gather(api.list_timeline(list_id))

    # NOTE 1: gather is a helper function to receive all data as list, FOR can be used as well:
    async for tweet in api.search("elon musk"):
        print(tweet.id, tweet.user.username, tweet.rawContent)  # tweet is `Tweet` object

    # NOTE 2: all methods have `raw` version (returns `httpx.Response` object):
    async for rep in api.search_raw("elon musk"):
        print(rep.status_code, rep.json())  # rep is `httpx.Response` object

    # change log level, default info
    set_log_level("DEBUG")

    # Tweet & User model can be converted to regular dict or json, e.g.:
    doc = await api.user_by_id(user_id)  # User
    doc.dict()  # -> python dict
    doc.json()  # -> json string

await main()
# if __name__ == "__main__":
#     asyncio.run(main())
# Out:
# 2023-11-15 00:33:04.870 | WARNING  | twscrape.accounts_pool:add_account:76 - Account csce60637593 already exists
# 1724676957487419437 CoinGem12 @DogeXparody Elon Musk is exceptionally talented and will achieve it swiftly.
# 1724676933336944721 Sbgmnmstnya @jek___ @elonmusk Tukin apa jek?
# 1724676926701461571 KituuWeh @jek___ @elonmusk Masih butuh rupanya stad?
# 1724676917905731587 RIYn0XqELPF @elonmusk You are a true master of your craft!
# 1724676917037547733 shaukatfrancis3 @elonmusk_xtr Hello Johli boys, how are you, may God bless you with a healthy life, Amen
# 1724676914785161384 JJDXBAI @Rwang29 @elonmusk @Port3Network 置顶三连谢谢
# @Port3Network #P3 #Port3 $wom
# 1724676901329879338 BRatnaker 🚀💰 Dojocoin Airdrop: The engine of my financial growth! 🚀
#
# Visit https://t.co/hbFgjKbziZ to claim Up to $30,000 DOJO
#
# ELON MUSK TWEETS
# https://t.co/qG53WDOqLA
# https://t.co/m0U6Q862Jp
# https://t.co/n6LK4teqCO https://t.co/orFDcjkAhG
# ...

# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level

async def main():
    api = API()
    cookies = "mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\"""mbox=session#00543142e1ef4a948358a901c70584b5#1678872819|PC#00543142e1ef4a948358a901c70584b5.38_0#1742115759; _ga_BYKEBDM7DS=GS1.1.1678870960.1.1.1678870978.0.0.0; _ga=GA1.2.1389436406.1671161874; g_state={\"i_l\":0}; amp_adc4c4=vuKDN2ksW3Mr2XuAXGHT_x...1guevbsif.1guevbsif.0.0.0; des_opt_in=Y; lang=en; _gid=GA1.2.202211142.1699999361; guest_id=v1%3A169999940018787061; guest_id_ads=v1%3A169999940018787061; guest_id_marketing=v1%3A169999940018787061; external_referer=padhuUp37zi4XoWogyFqcG77%2Fl8nbSDc1FOP28MQWuMcx6I0hrIE6%2FjiCI0TL4vixxJ%2Fdpru0H3fXlLXgkN%2BZDpoTZWxjOGc3DQW%2BXhYMtciHG3q%2B5%2B9qGbb4Gb1gJF%2BoAu%2F8vja6c4UfkekUpwNe4Zdc%2BBNNJQrciSWM57lxRTzI%2BiOGgo%2BeTuUpNQ8tklJVCVd4DRYEVFy%2B%2FsvJMc%2FFDf%2BlR%2F%2F5S5RBwlOumdevpkTIKFAG7359NiEI6oozOdKGRiPHP0jVeqeObW13wWDKnJ1fWm6K2%2Fui7rNs%2BuFXcbyzN30JSsodtMU7TObDC%2Flg4wBq2ITQIo%3D|0|8e8t2xd8A2w%3D; ads_prefs=\"HBIRAAA=\"; ct0=88c1a7457f8927749b2656e53f3d7c789d17b0a4921ac3c6fd6cbcdc477de42cc8cf77c6f643dce3ffa3a8ed45dd7c62ae055106b73500d8f63875aa342ec60360b9064561b00d2db3a8ab055460806f; twid=u%3D1724549647278952448; personalization_id=\"v1_wJl86kWozk37WT/R4q1NhA==\""
    await api.pool.add_account("csce60637593", "20010305", "csce606worker1@gmail.com", "P@ssw0rd!2001", cookies= cookies)
    await api.pool.login_all()

    q = "elon musk"
    # await gather(api.search(q, limit=20))  # list[Tweet]
    # change search tab (product), can be: Top, Latest (default), Media
    # await gather(api.search("elon musk", limit=20, kv={"product": "Top"}))
    # async for rep in api.search_raw("elon musk"):
        # print(rep.status_code, rep.json())  # rep is `httpx.Response` object
    # responses = []
    async for tweet in api.search("elon musk", limit = 5):
        # print(tweet.id, tweet.user.username, tweet.rawContent)  # tweet is `Tweet` object
        # rep is httpx.Response object
        print(tweet.id) 
        tweets.append(tweet)
        # print(rep.status_code, rep.json())
tweets = []
await main()
# if __name__ == "__main__":
    # asyncio.run(main())
# Out:
# 2023-11-15 00:58:30.147 | WARNING  | twscrape.accounts_pool:add_account:76 - Account csce60637593 already exists
# 1724683262940103040 bullishyong @ethgod95 @elonmusk $MUSK
# 1724683262940103040
# 1724683249409298771 lamhd136 @elonmusk hi, I give you a photo. https://t.co/ljkYocab8Z
# 1724683249409298771
# 1724683245768351827 DutchDeporable ELON AND TUCKER🙏❣❣❣💕
# Biden EXPLODES After Elon Musk &amp; Tucker Carlson DESTROY Him https://t.co/Kb2ClqOWpH via @YouTube
# 1724683245768351827
# 1724683207914688759 FREEDOM4JULIAN @tnworkinger @WellyFraisa @RaccooniusIV @achaw_bsss @jacksonhinklle @benshapiro @elonmusk Apparently it was an LBGTQ account hell I didn't know rhat it asked for a word that started with B &amp; ended with N next thing I know my account is totally disabled for hate speech
# 1724683207914688759
# 1724683207780581533 GloryToVoron @elonmusk_mudak https://t.co/jxxrXPXQAV
# 1724683207780581533

# %%
tweets[0]
# Out:
# Tweet(id=1724683262940103040, id_str='1724683262940103040', url='https://twitter.com/bullishyong/status/1724683262940103040', date=datetime.datetime(2023, 11, 15, 6, 58, 27, tzinfo=datetime.timezone.utc), user=User(id=1391243195367915520, id_str='1391243195367915520', url='https://twitter.com/bullishyong', username='bullishyong', displayname='MOON-BAGGER ❤️ Memecoin', rawDescription='OG @doodles | Seedling @RainbowAlpha_ | NinjaKat @CatsLabAlpha | Prof @WagmiUniversity | Kid @MBMweb3 | Collab Boi @BoisAlpha', created=datetime.datetime(2021, 5, 9, 4, 6, 56, tzinfo=datetime.timezone.utc), followersCount=5025, friendsCount=4189, statusesCount=5371, favouritesCount=33117, listedCount=21, mediaCount=443, location='au terra', profileImageUrl='https://pbs.twimg.com/profile_images/1710478025866035200/P07Z_HfL_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/1391243195367915520/1677988832', protected=None, verified=False, blue=False, blueType=None, descriptionLinks=[], _ty
# ...

# %% [markdown]
# # Modification on Scrapper
# 1. download chromdirver https://googlechromelabs.github.io/chrome-for-testing/#stable
# 2. change utils.py
# from selenium.webdriver.chrome.service import Service
# ...
# line147
# service = Service(executable_path=chromedriver_path)
# driver = webdriver.Chrome(options=options, service=service)

# %%
from Scweet.scweet import scrape
from Scweet.user import get_user_information, get_users_following, get_users_followers
from Scweet.utils import init_driver, log_in

# %%
driver = init_driver(headless=True, show_images=False)
log_in(driver, env=".env")
# data = scrape(..., driver=driver)
# Out:
# Scraping on headless mode.

# %%
data = scrape(words=['bitcoin','ethereum'], since="2021-10-01", until="2021-10-05", from_account = None, interval=1, headless=False, display_type="Top", save_images=False, lang="en",
	resume=False, filter_replies=False, proximity=False, geocode="38.3452,-0.481006,200km", driver=driver)
# Out:
# looking for tweets between 2021-10-01 and 2021-10-02 ...
#  path : https://twitter.com/search?q=(bitcoin%20OR%20ethereum)%20until%3A2021-10-02%20since%3A2021-10-01%20lang%3Aen%20geocode%3A38.3452,-0.481006,200km&src=typed_query
# scroll  1
# scroll  2
# looking for tweets between 2021-10-02 and 2021-10-03 ...
#  path : https://twitter.com/search?q=(bitcoin%20OR%20ethereum)%20until%3A2021-10-03%20since%3A2021-10-02%20lang%3Aen%20geocode%3A38.3452,-0.481006,200km&src=typed_query
# scroll  1
# scroll  2
# looking for tweets between 2021-10-03 and 2021-10-04 ...
#  path : https://twitter.com/search?q=(bitcoin%20OR%20ethereum)%20until%3A2021-10-04%20since%3A2021-10-03%20lang%3Aen%20geocode%3A38.3452,-0.481006,200km&src=typed_query
# scroll  1
# scroll  2
# looking for tweets between 2021-10-04 and 2021-10-05 ...
#  path : https://twitter.com/search?q=(bitcoin%20OR%20ethereum)%20until%3A2021-10-05%20since%3A2021-10-04%20lang%3Aen%20geocode%3A38.3452,-0.481006,200km&src=typed_query
# ...
